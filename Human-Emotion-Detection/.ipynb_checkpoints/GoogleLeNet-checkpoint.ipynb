# %% [markdown]
# # Human Emotion Detection using Deep Learning
#
# So our objective for today is try out basic model infrastructures and to determine what model should we finally use for our end product. We will choose the best accuracy model.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from keras import layers, models, optimizers, losses, metrics, callbacks
from keras.preprocessing.image import load_img, img_to_array
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Importing Data

# %%
pic_size = 48

# input path for the images
base_path = "/Users/tanmaysharma/Downloads/images/"

# %%
plt.figure(0, figsize=(12,20))
cpt = 0

for expression in os.listdir(base_path + "train"):
    for i in range(1,6):
        cpt = cpt + 1
        plt.subplot(7,5,cpt)
        img = load_img(base_path + "train/" + expression + "/" +os.listdir(base_path + "train/" + expression)[i], target_size=(pic_size, pic_size))
        plt.imshow(img, cmap="gray")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Image Augmentation using Image Data Generator

# %%
batch_size = 128

train_datagen = ImageDataGenerator(
    rescale = 1.0/255.0,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    rotation_range = 20,
    horizontal_flip = True
)

validation_datagen = ImageDataGenerator(rescale= 1.0/255)

train_generator = train_datagen.flow_from_directory(
    base_path + "train",
    target_size=(56,56),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    base_path + "validation",
    target_size=(56,56),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# ## Base Model

# %%
def convLoop(filters, kernel_size, strides, padding, pool_size, dropout):

    model = models.Sequential()

    model.add(layers.Conv2D(filters, kernel_size, strides, padding))
    model.add(layers.Activation('relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size))
    model.add(layers.Dropout(dropout))

    return model

# %%
def create_base_model():
    
    model = models.Sequential()

    model.add(layers.Input(shape = (56, 56, 1)))

    model.add(convLoop(filters=64, kernel_size=(3, 3), strides=(1, 1), padding='same', pool_size=(2, 2), dropout=0.25))
    model.add(convLoop(filters=128, kernel_size=(3, 3), strides=(1, 1), padding='same', pool_size=(2, 2), dropout=0.25))
    model.add(convLoop(filters=256, kernel_size=(3, 3), strides=(1, 1), padding='same', pool_size=(2, 2), dropout=0.25))
    model.add(convLoop(filters=512, kernel_size=(3, 3), strides=(1, 1), padding='same', pool_size=(2, 2), dropout=0.25))

    model.add(layers.Flatten())

    model.add(layers.Dense(512))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))
    model.add(layers.Dropout(0.25))

    model.add(layers.Dense(7, activation='softmax'))

    return model

# %%
def create_experiment(name, model):

    print('------------------------------------------------------------')
    print('------------------------------------------------------------')
    print('------------------------------------------------------------')
    print(f'--------------------{name} experiment----------------------')
    print('------------------------------------------------------------')
    print('------------------------------------------------------------')

    model.compile(
        optimizer = optimizers.legacy.Adam(learning_rate = 1e-3),
        loss = losses.CategoricalCrossentropy(),
        metrics = metrics.CategoricalAccuracy()
    )

    model.summary()

    reducelr = callbacks.ReduceLROnPlateau(patience = 5, factor = 0.15)
    early_stopping = callbacks.EarlyStopping(patience = 10)

    history = model.fit_generator(
        generator=train_generator,
        steps_per_epoch=train_generator.n//train_generator.batch_size,
        epochs=150,
        validation_data = validation_generator,
        validation_steps = validation_generator.n//validation_generator.batch_size,
        callbacks= (reducelr, early_stopping)
    )

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Plot training and validation categorical accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['categorical_accuracy'], label='Training Categorical Accuracy')
    plt.plot(history.history['val_categorical_accuracy'], label='Validation Categorical Accuracy')
    plt.title('Training and Validation Categorical Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Categorical Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()
        
    return history

# %%
baseline_model = create_base_model()
history_baseline = create_experiment('Baseline', baseline_model)
# Out:
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# --------------------Baseline experiment----------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_21 (Sequential)  (None, 28, 28, 64)        896
#
#  sequential_22 (Sequential)  (None, 14, 14, 128)       74368
#
#  sequential_23 (Sequential)  (None, 7, 7, 256)         296192
#
#  sequential_24 (Sequential)  (None, 3, 3, 512)         1182208
#
#  flatten_4 (Flatten)         (None, 4608)              0
#
#  dense_8 (Dense)             (None, 512)               2359808
#
#  batch_normalization_24 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 512)               0
#
#  dropout_24 (Dropout)        (None, 512)               0
#
#  dense_9 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 3919111 (14.95 MB)
# Trainable params: 3916167 (14.94 MB)
# Non-trainable params: 2944 (11.50 KB)
# _________________________________________________________________
# Epoch 1/150
# /var/folders/f1/19ck_yvd7p355g2p8r2jyzlc0000gn/T/ipykernel_16716/1235298395.py:21: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 225/225 [==============================] - 35s 126ms/step - loss: 1.8296 - categorical_accuracy: 0.2838 - val_loss: 2.0214 - val_categorical_accuracy: 0.1801 - lr: 0.0010
# Epoch 2/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.5359 - categorical_accuracy: 0.4043 - val_loss: 1.5984 - val_categorical_accuracy: 0.3575 - lr: 0.0010
# Epoch 3/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.3913 - categorical_accuracy: 0.4669 - val_loss: 1.3418 - val_categorical_accuracy: 0.4814 - lr: 0.0010
# Epoch 4/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.3138 - categorical_accuracy: 0.4982 - val_loss: 1.2107 - val_categorical_accuracy: 0.5402 - lr: 0.0010
# Epoch 5/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.2591 - categorical_accuracy: 0.5217 - val_loss: 1.2633 - val_categorical_accuracy: 0.5259 - lr: 0.0010
# Epoch 6/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.2217 - categorical_accuracy: 0.5355 - val_loss: 1.1329 - val_categorical_accuracy: 0.5662 - lr: 0.0010
# Epoch 7/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.1861 - categorical_accuracy: 0.5481 - val_loss: 1.2152 - val_categorical_accuracy: 0.5409 - lr: 0.0010
# Epoch 8/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.1563 - categorical_accuracy: 0.5601 - val_loss: 1.1437 - val_categorical_accuracy: 0.5693 - lr: 0.0010
# Epoch 9/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.1348 - categorical_accuracy: 0.5698 - val_loss: 1.1026 - val_categorical_accuracy: 0.5875 - lr: 0.0010
# Epoch 10/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.1161 - categorical_accuracy: 0.5776 - val_loss: 1.1146 - val_categorical_accuracy: 0.5849 - lr: 0.0010
# Epoch 11/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.0974 - categorical_accuracy: 0.5859 - val_loss: 1.1168 - val_categorical_accuracy: 0.5942 - lr: 0.0010
# Epoch 12/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.0803 - categorical_accuracy: 0.5902 - val_loss: 1.0380 - val_categorical_accuracy: 0.6053 - lr: 0.0010
# Epoch 13/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.0641 - categorical_accuracy: 0.5964 - val_loss: 1.0792 - val_categorical_accuracy: 0.5916 - lr: 0.0010
# Epoch 14/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.0583 - categorical_accuracy: 0.5971 - val_loss: 1.0409 - val_categorical_accuracy: 0.6085 - lr: 0.0010
# Epoch 15/150
# 225/225 [==============================] - 25s 109ms/step - loss: 1.0415 - categorical_accuracy: 0.6046 - val_loss: 1.1625 - val_categorical_accuracy: 0.5557 - lr: 0.0010
# Epoch 16/150
# 225/225 [==============================] - 24s 108ms/step - loss: 1.0360 - categorical_accuracy: 0.6084 - val_loss: 1.1642 - val_categorical_accuracy: 0.5648 - lr: 0.0010
# Epoch 17/150
# 225/225 [==============================] - 25s 109ms/step - loss: 1.0247 - categorical_accuracy: 0.6124 - val_loss: 1.0242 - val_categorical_accuracy: 0.6193 - lr: 0.0010
# Epoch 18/150
# 225/225 [==============================] - 25s 109ms/step - loss: 1.0110 - categorical_accuracy: 0.6190 - val_loss: 1.0535 - val_categorical_accuracy: 0.6003 - lr: 0.0010
# Epoch 19/150
# 225/225 [==============================] - 24s 109ms/step - loss: 0.9951 - categorical_accuracy: 0.6236 - val_loss: 0.9947 - val_categorical_accuracy: 0.6317 - lr: 0.0010
# Epoch 20/150
# 225/225 [==============================] - 24s 108ms/step - loss: 0.9935 - categorical_accuracy: 0.6222 - val_loss: 1.1351 - val_categorical_accuracy: 0.5817 - lr: 0.0010
# Epoch 21/150
# 225/225 [==============================] - 24s 108ms/step - loss: 0.9794 - categorical_accuracy: 0.6289 - val_loss: 1.3071 - val_categorical_accuracy: 0.5337 - lr: 0.0010
# Epoch 22/150
# 225/225 [==============================] - 24s 108ms/step - loss: 0.9634 - categorical_accuracy: 0.6345 - val_loss: 1.0304 - val_categorical_accuracy: 0.6178 - lr: 0.0010
# Epoch 23/150
# 225/225 [==============================] - 25s 109ms/step - loss: 0.9591 - categorical_accuracy: 0.6387 - val_loss: 1.0498 - val_categorical_accuracy: 0.6249 - lr: 0.0010
# Epoch 24/150
# 225/225 [==============================] - 24s 108ms/step - loss: 0.9530 - categorical_accuracy: 0.6417 - val_loss: 1.0626 - val_categorical_accuracy: 0.6051 - lr: 0.0010
# Epoch 25/150
# 225/225 [==============================] - 24s 109ms/step - loss: 0.9091 - categorical_accuracy: 0.6572 - val_loss: 0.9670 - val_categorical_accuracy: 0.6409 - lr: 1.5000e-04
# Epoch 26/150
# 225/225 [==============================] - 24s 109ms/step - loss: 0.8981 - categorical_accuracy: 0.6607 - val_loss: 0.9562 - val_categorical_accuracy: 0.6517 - lr: 1.5000e-04
# Epoch 27/150
# 225/225 [==============================] - 24s 109ms/step - loss: 0.8906 - categorical_accuracy: 0.6667 - val_loss: 0.9501 - val_categorical_accuracy: 0.6486 - lr: 1.5000e-04
# Epoch 28/150
# 225/225 [==============================] - 98s 437ms/step - loss: 0.8799 - categorical_accuracy: 0.6697 - val_loss: 0.9406 - val_categorical_accuracy: 0.6560 - lr: 1.5000e-04
# Epoch 29/150
# 225/225 [==============================] - 24s 108ms/step - loss: 0.8769 - categorical_accuracy: 0.6718 - val_loss: 0.9262 - val_categorical_accuracy: 0.6602 - lr: 1.5000e-04
# Epoch 30/150
# 225/225 [==============================] - 182s 814ms/step - loss: 0.8643 - categorical_accuracy: 0.6771 - val_loss: 0.9530 - val_categorical_accuracy: 0.6503 - lr: 1.5000e-04
# Epoch 31/150
# 225/225 [==============================] - 24s 107ms/step - loss: 0.8583 - categorical_accuracy: 0.6793 - val_loss: 0.9349 - val_categorical_accuracy: 0.6597 - lr: 1.5000e-04
# Epoch 32/150
# 225/225 [==============================] - 646s 3s/step - loss: 0.8583 - categorical_accuracy: 0.6743 - val_loss: 0.9273 - val_categorical_accuracy: 0.6624 - lr: 1.5000e-04
# Epoch 33/150
# 225/225 [==============================] - 24s 107ms/step - loss: 0.8564 - categorical_accuracy: 0.6769 - val_loss: 0.9367 - val_categorical_accuracy: 0.6547 - lr: 1.5000e-04
# Epoch 34/150
# 225/225 [==============================] - 24s 107ms/step - loss: 0.8502 - categorical_accuracy: 0.6807 - val_loss: 0.9304 - val_categorical_accuracy: 0.6571 - lr: 1.5000e-04
# Epoch 35/150
# 225/225 [==============================] - 24s 107ms/step - loss: 0.8362 - categorical_accuracy: 0.6880 - val_loss: 0.9289 - val_categorical_accuracy: 0.6595 - lr: 2.2500e-05
# Epoch 36/150
# 225/225 [==============================] - 24s 108ms/step - loss: 0.8383 - categorical_accuracy: 0.6862 - val_loss: 0.9345 - val_categorical_accuracy: 0.6562 - lr: 2.2500e-05
# Epoch 37/150
# 225/225 [==============================] - 24s 108ms/step - loss: 0.8360 - categorical_accuracy: 0.6899 - val_loss: 0.9282 - val_categorical_accuracy: 0.6595 - lr: 2.2500e-05
# Epoch 38/150
# 225/225 [==============================] - 24s 107ms/step - loss: 0.8287 - categorical_accuracy: 0.6881 - val_loss: 0.9341 - val_categorical_accuracy: 0.6558 - lr: 2.2500e-05
# Epoch 39/150
# 225/225 [==============================] - 24s 107ms/step - loss: 0.8278 - categorical_accuracy: 0.6916 - val_loss: 0.9354 - val_categorical_accuracy: 0.6551 - lr: 2.2500e-05

# %% [markdown]
# ## Model with a different approach for setting convolutions and poolings

# %%
def alternative_conv_layers(filters, kernel_size, strides, padding, pool_size, dropout, num_blocks):

    model = models.Sequential()

    for i in filters:
        for _ in range(num_blocks):
            model.add(layers.Conv2D(i, kernel_size, strides, padding))
            model.add(layers.Activation('relu'))
            model.add(layers.BatchNormalization())
        model.add(layers.MaxPooling2D(pool_size))
        model.add(layers.Dropout(dropout))
    
    return model

# %%
def create_alt_conv_model(filters = [64, 128, 256, 512]):
    
    model = models.Sequential()

    model.add(layers.Input(shape = (56, 56, 1)))

    model.add(alternative_conv_layers(filters=filters, kernel_size=(3, 3), strides=(1, 1), padding='same', pool_size=(2, 2), dropout=0.25, num_blocks = 2))
    
    model.add(layers.Flatten())

    model.add(layers.Dense(512))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))
    model.add(layers.Dropout(0.25))

    model.add(layers.Dense(7, activation='softmax'))

    return model

# %%
alt_conv_model = create_alt_conv_model()
history_alt_conv_model = create_experiment('Alternative Conv', alt_conv_model)
# Out:
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# --------------------Alternative Conv experiment----------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_26 (Sequential)  (None, 3, 3, 512)         4691904
#
#  flatten_5 (Flatten)         (None, 4608)              0
#
#  dense_10 (Dense)            (None, 512)               2359808
#
#  batch_normalization_33 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 512)               0
#
#  dropout_29 (Dropout)        (None, 512)               0
#
#  dense_11 (Dense)            (None, 7)                 3591
#
# =================================================================
# Total params: 7057351 (26.92 MB)
# Trainable params: 7052487 (26.90 MB)
# Non-trainable params: 4864 (19.00 KB)
# _________________________________________________________________
# Epoch 1/150
# /var/folders/f1/19ck_yvd7p355g2p8r2jyzlc0000gn/T/ipykernel_16716/1235298395.py:21: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 225/225 [==============================] - 56s 212ms/step - loss: 1.8246 - categorical_accuracy: 0.2882 - val_loss: 1.7959 - val_categorical_accuracy: 0.2614 - lr: 0.0010
# Epoch 2/150
# 225/225 [==============================] - 43s 190ms/step - loss: 1.4755 - categorical_accuracy: 0.4308 - val_loss: 1.6500 - val_categorical_accuracy: 0.4107 - lr: 0.0010
# Epoch 3/150
# 225/225 [==============================] - 43s 191ms/step - loss: 1.3066 - categorical_accuracy: 0.4995 - val_loss: 1.3578 - val_categorical_accuracy: 0.4938 - lr: 0.0010
# Epoch 4/150
# 225/225 [==============================] - 43s 192ms/step - loss: 1.2196 - categorical_accuracy: 0.5371 - val_loss: 1.2847 - val_categorical_accuracy: 0.5234 - lr: 0.0010
# Epoch 5/150
# 225/225 [==============================] - 43s 191ms/step - loss: 1.1561 - categorical_accuracy: 0.5625 - val_loss: 1.3087 - val_categorical_accuracy: 0.4955 - lr: 0.0010
# Epoch 6/150
# 225/225 [==============================] - 43s 191ms/step - loss: 1.1082 - categorical_accuracy: 0.5802 - val_loss: 1.1234 - val_categorical_accuracy: 0.5739 - lr: 0.0010
# Epoch 7/150
# 225/225 [==============================] - 43s 191ms/step - loss: 1.0756 - categorical_accuracy: 0.5937 - val_loss: 1.1170 - val_categorical_accuracy: 0.5842 - lr: 0.0010
# Epoch 8/150
# 225/225 [==============================] - 43s 191ms/step - loss: 1.0447 - categorical_accuracy: 0.6061 - val_loss: 1.1123 - val_categorical_accuracy: 0.5794 - lr: 0.0010
# Epoch 9/150
# 225/225 [==============================] - 43s 191ms/step - loss: 1.0199 - categorical_accuracy: 0.6156 - val_loss: 1.1171 - val_categorical_accuracy: 0.5869 - lr: 0.0010
# Epoch 10/150
# 225/225 [==============================] - 944s 4s/step - loss: 0.9968 - categorical_accuracy: 0.6243 - val_loss: 1.0507 - val_categorical_accuracy: 0.6036 - lr: 0.0010
# Epoch 11/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.9754 - categorical_accuracy: 0.6305 - val_loss: 0.9842 - val_categorical_accuracy: 0.6287 - lr: 0.0010
# Epoch 12/150
# 225/225 [==============================] - 943s 4s/step - loss: 0.9532 - categorical_accuracy: 0.6407 - val_loss: 1.0092 - val_categorical_accuracy: 0.6293 - lr: 0.0010
# Epoch 13/150
# 225/225 [==============================] - 943s 4s/step - loss: 0.9376 - categorical_accuracy: 0.6467 - val_loss: 1.0960 - val_categorical_accuracy: 0.5955 - lr: 0.0010
# Epoch 14/150
# 225/225 [==============================] - 943s 4s/step - loss: 0.9195 - categorical_accuracy: 0.6522 - val_loss: 1.1534 - val_categorical_accuracy: 0.5892 - lr: 0.0010
# Epoch 15/150
# 225/225 [==============================] - 43s 189ms/step - loss: 0.9069 - categorical_accuracy: 0.6598 - val_loss: 1.0682 - val_categorical_accuracy: 0.6267 - lr: 0.0010
# Epoch 16/150
# 225/225 [==============================] - 948s 4s/step - loss: 0.8907 - categorical_accuracy: 0.6656 - val_loss: 0.9694 - val_categorical_accuracy: 0.6332 - lr: 0.0010
# Epoch 17/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.8837 - categorical_accuracy: 0.6696 - val_loss: 1.0767 - val_categorical_accuracy: 0.6091 - lr: 0.0010
# Epoch 18/150
# 225/225 [==============================] - 44s 194ms/step - loss: 0.8543 - categorical_accuracy: 0.6788 - val_loss: 0.9592 - val_categorical_accuracy: 0.6537 - lr: 0.0010
# Epoch 19/150
# 225/225 [==============================] - 51s 226ms/step - loss: 0.8481 - categorical_accuracy: 0.6836 - val_loss: 1.0172 - val_categorical_accuracy: 0.6314 - lr: 0.0010
# Epoch 20/150
# 225/225 [==============================] - 259s 1s/step - loss: 0.8339 - categorical_accuracy: 0.6887 - val_loss: 1.0439 - val_categorical_accuracy: 0.6287 - lr: 0.0010
# Epoch 21/150
# 225/225 [==============================] - 43s 192ms/step - loss: 0.8172 - categorical_accuracy: 0.6941 - val_loss: 0.9293 - val_categorical_accuracy: 0.6592 - lr: 0.0010
# Epoch 22/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.8002 - categorical_accuracy: 0.6977 - val_loss: 0.9791 - val_categorical_accuracy: 0.6429 - lr: 0.0010
# Epoch 23/150
# 225/225 [==============================] - 43s 192ms/step - loss: 0.7928 - categorical_accuracy: 0.7007 - val_loss: 0.9648 - val_categorical_accuracy: 0.6565 - lr: 0.0010
# Epoch 24/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.7734 - categorical_accuracy: 0.7117 - val_loss: 0.9415 - val_categorical_accuracy: 0.6599 - lr: 0.0010
# Epoch 25/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.7597 - categorical_accuracy: 0.7144 - val_loss: 1.0192 - val_categorical_accuracy: 0.6517 - lr: 0.0010
# Epoch 26/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.7509 - categorical_accuracy: 0.7199 - val_loss: 0.9698 - val_categorical_accuracy: 0.6526 - lr: 0.0010
# Epoch 27/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.6767 - categorical_accuracy: 0.7463 - val_loss: 0.9213 - val_categorical_accuracy: 0.6753 - lr: 1.5000e-04
# Epoch 28/150
# 225/225 [==============================] - 44s 194ms/step - loss: 0.6490 - categorical_accuracy: 0.7574 - val_loss: 0.9287 - val_categorical_accuracy: 0.6780 - lr: 1.5000e-04
# Epoch 29/150
# 225/225 [==============================] - 43s 192ms/step - loss: 0.6305 - categorical_accuracy: 0.7653 - val_loss: 0.9555 - val_categorical_accuracy: 0.6729 - lr: 1.5000e-04
# Epoch 30/150
# 225/225 [==============================] - 43s 192ms/step - loss: 0.6178 - categorical_accuracy: 0.7689 - val_loss: 0.9413 - val_categorical_accuracy: 0.6756 - lr: 1.5000e-04
# Epoch 31/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.6059 - categorical_accuracy: 0.7751 - val_loss: 0.9639 - val_categorical_accuracy: 0.6768 - lr: 1.5000e-04
# Epoch 32/150
# 225/225 [==============================] - 44s 193ms/step - loss: 0.5947 - categorical_accuracy: 0.7798 - val_loss: 0.9772 - val_categorical_accuracy: 0.6727 - lr: 1.5000e-04
# Epoch 33/150
# 225/225 [==============================] - 43s 193ms/step - loss: 0.5846 - categorical_accuracy: 0.7809 - val_loss: 0.9647 - val_categorical_accuracy: 0.6759 - lr: 2.2500e-05
# Epoch 34/150
# 225/225 [==============================] - 43s 193ms/step - loss: 0.5736 - categorical_accuracy: 0.7887 - val_loss: 0.9637 - val_categorical_accuracy: 0.6756 - lr: 2.2500e-05
# Epoch 35/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.5747 - categorical_accuracy: 0.7842 - val_loss: 0.9694 - val_categorical_accuracy: 0.6766 - lr: 2.2500e-05
# Epoch 36/150
# 225/225 [==============================] - 43s 192ms/step - loss: 0.5738 - categorical_accuracy: 0.7855 - val_loss: 0.9713 - val_categorical_accuracy: 0.6767 - lr: 2.2500e-05
# Epoch 37/150
# 225/225 [==============================] - 43s 193ms/step - loss: 0.5689 - categorical_accuracy: 0.7870 - val_loss: 0.9740 - val_categorical_accuracy: 0.6777 - lr: 2.2500e-05

# %% [markdown]
# ## Copying a Mini Version of the GoogleLeNet/InceptionV3 Architecture

# %%
def inception_module(x, filters):
    
    conv1x1_1 = layers.Conv2D(filters[0], (1, 1), padding='same', activation='relu')(x)
    conv3x3 = layers.Conv2D(filters[1], (3, 3), padding='same', activation='relu')(x)
    conv5x5 = layers.Conv2D(filters[2], (5, 5), padding='same', activation='relu')(x)
    max_pool = layers.MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    conv1x1_2 = layers.Conv2D(filters[3], (1, 1), padding='same', activation='relu')(max_pool)

    inception_block = layers.concatenate([conv1x1_1, conv3x3, conv5x5, conv1x1_2], axis=-1)

    return inception_block

# %%
def inception_blocks():

    input_layer = layers.Input(shape=(56, 56, 1))  # Adjust input shape as needed

    # First block
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(input_layer)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    
    # Second block
    x = layers.Conv2D(64, (1, 1), padding='same', activation='relu')(x)
    x = layers.Conv2D(192, (3, 3), padding='same', activation='relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    
    # Inception modules
    x = inception_module(x, [64, 128, 32, 32])
    x = inception_module(x, [128, 192, 96, 64])
    
    # Add more inception modules as needed
    
    # Global Average Pooling
    x = layers.AveragePooling2D((7, 7))(x)
    
    # Flatten and Dense layers for classification
    x = layers.Flatten()(x)
    x = layers.Dense(units=1000, activation='relu')(x) 
    output_layer = layers.Dense(units = 7, activation = 'softmax')(x)

    return models.Model(input_layer, output_layer)

# %%
inception_base_model = inception_blocks()

# %%
inception_base_model = create_experiment('Inception Base Experiment', inception_base_model)
# Out:
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# --------------------Inception Base Experiment experiment----------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_10 (InputLayer)       [(None, 56, 56, 1)]          0         []
#
#  conv2d_53 (Conv2D)          (None, 28, 28, 64)           3200      ['input_10[0][0]']
#
#  max_pooling2d_34 (MaxPooli  (None, 14, 14, 64)           0         ['conv2d_53[0][0]']
#  ng2D)
#
#  conv2d_54 (Conv2D)          (None, 14, 14, 64)           4160      ['max_pooling2d_34[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 14, 14, 192)          110784    ['conv2d_54[0][0]']
#
#  max_pooling2d_35 (MaxPooli  (None, 7, 7, 192)            0         ['conv2d_55[0][0]']
#  ng2D)
#
#  max_pooling2d_36 (MaxPooli  (None, 7, 7, 192)            0         ['max_pooling2d_35[0][0]']
#  ng2D)
#
#  conv2d_56 (Conv2D)          (None, 7, 7, 64)             12352     ['max_pooling2d_35[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 7, 7, 128)            221312    ['max_pooling2d_35[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 7, 7, 32)             153632    ['max_pooling2d_35[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 7, 7, 32)             6176      ['max_pooling2d_36[0][0]']
#
#  concatenate_4 (Concatenate  (None, 7, 7, 256)            0         ['conv2d_56[0][0]',
#  )                                                                   'conv2d_57[0][0]',
#                                                                      'conv2d_58[0][0]',
#                                                                      'conv2d_59[0][0]']
#
#  max_pooling2d_37 (MaxPooli  (None, 7, 7, 256)            0         ['concatenate_4[0][0]']
#  ng2D)
#
#  conv2d_60 (Conv2D)          (None, 7, 7, 128)            32896     ['concatenate_4[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 7, 7, 192)            442560    ['concatenate_4[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 7, 7, 96)             614496    ['concatenate_4[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 7, 7, 64)             16448     ['max_pooling2d_37[0][0]']
#
#  concatenate_5 (Concatenate  (None, 7, 7, 480)            0         ['conv2d_60[0][0]',
#  )                                                                   'conv2d_61[0][0]',
#                                                                      'conv2d_62[0][0]',
#                                                                      'conv2d_63[0][0]']
#
#  average_pooling2d_2 (Avera  (None, 1, 1, 480)            0         ['concatenate_5[0][0]']
#  gePooling2D)
#
#  flatten_8 (Flatten)         (None, 480)                  0         ['average_pooling2d_2[0][0]']
#
#  dense_16 (Dense)            (None, 1000)                 481000    ['flatten_8[0][0]']
#
#  dense_17 (Dense)            (None, 7)                    7007      ['dense_16[0][0]']
#
# ==================================================================================================
# Total params: 2106023 (8.03 MB)
# Trainable params: 2106023 (8.03 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/150
# /var/folders/f1/19ck_yvd7p355g2p8r2jyzlc0000gn/T/ipykernel_16716/1235298395.py:21: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 225/225 [==============================] - 31s 107ms/step - loss: 1.8066 - categorical_accuracy: 0.2507 - val_loss: 1.7856 - val_categorical_accuracy: 0.2605 - lr: 0.0010
# Epoch 2/150
# 225/225 [==============================] - 19s 83ms/step - loss: 1.7877 - categorical_accuracy: 0.2551 - val_loss: 1.8377 - val_categorical_accuracy: 0.2151 - lr: 0.0010
# Epoch 3/150
# 225/225 [==============================] - 19s 84ms/step - loss: 1.7537 - categorical_accuracy: 0.2773 - val_loss: 1.6950 - val_categorical_accuracy: 0.3139 - lr: 0.0010
# Epoch 4/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.6911 - categorical_accuracy: 0.3140 - val_loss: 1.6207 - val_categorical_accuracy: 0.3501 - lr: 0.0010
# Epoch 5/150
# 225/225 [==============================] - 19s 84ms/step - loss: 1.6100 - categorical_accuracy: 0.3643 - val_loss: 1.5850 - val_categorical_accuracy: 0.3884 - lr: 0.0010
# Epoch 6/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.5534 - categorical_accuracy: 0.3956 - val_loss: 1.4631 - val_categorical_accuracy: 0.4412 - lr: 0.0010
# Epoch 7/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.4904 - categorical_accuracy: 0.4271 - val_loss: 1.4433 - val_categorical_accuracy: 0.4484 - lr: 0.0010
# Epoch 8/150
# 225/225 [==============================] - 19s 84ms/step - loss: 1.4646 - categorical_accuracy: 0.4381 - val_loss: 1.4230 - val_categorical_accuracy: 0.4690 - lr: 0.0010
# Epoch 9/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.4345 - categorical_accuracy: 0.4506 - val_loss: 1.3878 - val_categorical_accuracy: 0.4741 - lr: 0.0010
# Epoch 10/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.4187 - categorical_accuracy: 0.4563 - val_loss: 1.3436 - val_categorical_accuracy: 0.4942 - lr: 0.0010
# Epoch 11/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.3979 - categorical_accuracy: 0.4661 - val_loss: 1.3852 - val_categorical_accuracy: 0.4800 - lr: 0.0010
# Epoch 12/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.4054 - categorical_accuracy: 0.4667 - val_loss: 1.3978 - val_categorical_accuracy: 0.4703 - lr: 0.0010
# Epoch 13/150
# 225/225 [==============================] - 20s 88ms/step - loss: 1.3818 - categorical_accuracy: 0.4728 - val_loss: 1.3717 - val_categorical_accuracy: 0.4855 - lr: 0.0010
# Epoch 14/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.4066 - categorical_accuracy: 0.4655 - val_loss: 1.3702 - val_categorical_accuracy: 0.4984 - lr: 0.0010
# Epoch 15/150
# 225/225 [==============================] - 19s 84ms/step - loss: 1.3929 - categorical_accuracy: 0.4752 - val_loss: 1.4415 - val_categorical_accuracy: 0.4805 - lr: 0.0010
# Epoch 16/150
# 225/225 [==============================] - 19s 84ms/step - loss: 1.2962 - categorical_accuracy: 0.5062 - val_loss: 1.2658 - val_categorical_accuracy: 0.5178 - lr: 1.5000e-04
# Epoch 17/150
# 225/225 [==============================] - 19s 86ms/step - loss: 1.2890 - categorical_accuracy: 0.5094 - val_loss: 1.2821 - val_categorical_accuracy: 0.5111 - lr: 1.5000e-04
# Epoch 18/150
# 225/225 [==============================] - 20s 87ms/step - loss: 1.2902 - categorical_accuracy: 0.5116 - val_loss: 1.2892 - val_categorical_accuracy: 0.5129 - lr: 1.5000e-04
# Epoch 19/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.2980 - categorical_accuracy: 0.5074 - val_loss: 1.2518 - val_categorical_accuracy: 0.5224 - lr: 1.5000e-04
# Epoch 20/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.2862 - categorical_accuracy: 0.5112 - val_loss: 1.2801 - val_categorical_accuracy: 0.5188 - lr: 1.5000e-04
# Epoch 21/150
# 225/225 [==============================] - 19s 84ms/step - loss: 1.2888 - categorical_accuracy: 0.5129 - val_loss: 1.2708 - val_categorical_accuracy: 0.5161 - lr: 1.5000e-04
# Epoch 22/150
# 225/225 [==============================] - 19s 84ms/step - loss: 1.2888 - categorical_accuracy: 0.5103 - val_loss: 1.2819 - val_categorical_accuracy: 0.5202 - lr: 1.5000e-04
# Epoch 23/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.2845 - categorical_accuracy: 0.5116 - val_loss: 1.2784 - val_categorical_accuracy: 0.5212 - lr: 1.5000e-04
# Epoch 24/150
# 225/225 [==============================] - 19s 84ms/step - loss: 1.2783 - categorical_accuracy: 0.5129 - val_loss: 1.2850 - val_categorical_accuracy: 0.5095 - lr: 1.5000e-04
# Epoch 25/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.2506 - categorical_accuracy: 0.5266 - val_loss: 1.2435 - val_categorical_accuracy: 0.5277 - lr: 2.2500e-05
# Epoch 26/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.2451 - categorical_accuracy: 0.5249 - val_loss: 1.2451 - val_categorical_accuracy: 0.5276 - lr: 2.2500e-05
# Epoch 27/150
# 225/225 [==============================] - 19s 84ms/step - loss: 1.2507 - categorical_accuracy: 0.5254 - val_loss: 1.2475 - val_categorical_accuracy: 0.5253 - lr: 2.2500e-05
# Epoch 28/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.2532 - categorical_accuracy: 0.5249 - val_loss: 1.2486 - val_categorical_accuracy: 0.5253 - lr: 2.2500e-05
# Epoch 29/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.2496 - categorical_accuracy: 0.5255 - val_loss: 1.2552 - val_categorical_accuracy: 0.5243 - lr: 2.2500e-05
# Epoch 30/150
# 225/225 [==============================] - 19s 86ms/step - loss: 1.2448 - categorical_accuracy: 0.5242 - val_loss: 1.2505 - val_categorical_accuracy: 0.5213 - lr: 2.2500e-05
# Epoch 31/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.2483 - categorical_accuracy: 0.5250 - val_loss: 1.2455 - val_categorical_accuracy: 0.5253 - lr: 3.3750e-06
# Epoch 32/150
# 225/225 [==============================] - 19s 86ms/step - loss: 1.2445 - categorical_accuracy: 0.5245 - val_loss: 1.2439 - val_categorical_accuracy: 0.5257 - lr: 3.3750e-06
# Epoch 33/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.2455 - categorical_accuracy: 0.5274 - val_loss: 1.2436 - val_categorical_accuracy: 0.5236 - lr: 3.3750e-06
# Epoch 34/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.2427 - categorical_accuracy: 0.5262 - val_loss: 1.2448 - val_categorical_accuracy: 0.5249 - lr: 3.3750e-06
# Epoch 35/150
# 225/225 [==============================] - 19s 85ms/step - loss: 1.2432 - categorical_accuracy: 0.5258 - val_loss: 1.2435 - val_categorical_accuracy: 0.5276 - lr: 3.3750e-06

# %% [markdown]
# ## Conclusions
#
# 1. Base accuracy for future tuning is 70%.
# 2. Tranfer learning base accuracy should be around 75%.
# 3. Idea 2 got a little overfit, so we cannot use an even deeper network.
